# %% [markdown]
# <img src = 'https://raw.githubusercontent.com/iampankajspatil/IPL-Project-Insaid-Term-1/07fa971970b3078837d877d1bd5a6ad275eb293b/Indian_Premier_League_IPL.png' width=300, height=300>
#
# # Indian Premier League
#    ------

# %% [markdown]
# ### Table of Contents
# - 1. [Problem Statement](#pb)</br>
#     - 1.1 [Introduction](#intro)<br/>
#     - 1.2 [Data source and data set](#section102)<br/>
# - 2. [Load the packages and data](#section2)</br>
# - 3. [Data profiling](#section3)</br>
#     - 3.1 [Understanding the Dataset](#section301)<br/>
#     - 3.2 [Pre Profiling](#section302)<br/>
#     - 3.3 [Preprocessing](#section303)<br/>
#     - 3.4 [Post Profiling](#section304)<br/>
# - 4. [Questions](#section4)
#     - 4.1 [How many seasons we’ve got in the dataset?](#section401)<br/>
#     - 4.2 [Which Team had won by maximum runs?](#section402)<br/>
#     - 4.3 [Which Team had won by maximum wicket?](#section403)<br/>
#     - 4.4 [Which Season had most number of matches?](#section404)<br/>
#     - 4.5 [Which IPL Team is more successful?](#section405)<br/>
#     - 4.6 [Which player has won maximum player of the match award?](#section406)<br/>
#     - 4.7 [Has Toss-winning helped in winning matches?](#section407)<br/>
#     - 4.8 [IPL matches played in which stadiums?](#section408)<br/>
#     - 4.9 [Which Team is best in defending the total?](#section409)<br/>
#     - 4.10 [Which Team is best in chasing the target?](#section410)<br/>
#     - 4.11 [Which is the best venue to defend the total?](#section411)<br/>
#     - 4.12 [Which is the best venue to chase the target?](#section412)<br/>
#     - 4.13 [Venue wise result!](#section413)<br/>
#     - 4.14 [Which player received the maximum number of Player of Match award while defending the total?](#section414)<br/>
#     - 4.15 [Which player received the maximum number of Player of Match award while chasing the target?](#section415)<br/>
#     - 4.16 [Player of the Match - Match wise result](#section416)<br/>
#     - 4.17 [Venue & Player of The Match wise results!](#section417)<br/>
# - 5. [Conclusion](#section5)<br/>

# %% [markdown]
# <a id="pb"></a>
# ### 1. Problem Statement
# "This dataset is from a 2018 iplt20.com that shows all the matches with their results of all IPL seasons played from year 2008 till 2018."
#
# Using his dataset we are going to analyis our following things:-
#
# 1. How many seasons we’ve got in the dataset?
#
# 2. Which Team had won by maximum runs?
#
# 3. Which Team had won by maximum wicket?
#
# 4. Which Season had most number of matches?
#
# 5. Which IPL Team is more successful?
#
# 6. Which player has won maximum player of the match award?
#
# 7. Has Toss-winning helped in winning matches?
#
# 8. IPL matches played in which stadiums?
#
# 9. Which Team is best in defending the total?
#
# 10. Which Team is best in chasing the target?
#
# 11. Which the best venue to defend the total?
#
# 12. Which the best venue to chase the target?
#
# 13. Venue wise result!
#
# 14. Which player received the maximum number of Player of Match award while defending the total?
#
# 15. Which player received the maximum number of Player of Match award while chasing the target?
#
# 16. Player of The Match - Match wise results!
#
# 17. Venue & Player of The Match wise results!

# %% [markdown]
# <a id=intro></a>
# ### 1.1. Introduction
#
# **The Indian Premier League (IPL)**, officially Vivo Indian Premier League for sponsorship reasons, is a professional Twenty20 cricket league in India contested during April and May of every year by teams representing Indian cities and some states.The league was founded by the **Board of Control for Cricket in India (BCCI)** in 2008, and is regarded as the brainchild of Lalit Modi, the founder and former commissioner of the league. IPL has an exclusive window in ICC Future Tours Programme.
#
# The IPL is the most-attended cricket league in the world and in 2014 ranked sixth by average attendance among all sports leagues.In 2010, the IPL became the first sporting event in the world to be broadcast live on YouTube.**The brand value of IPL in 2018 was (US dollar 6.3 billion), according to Duff & Phelps. According to BCCI, the 2015 IPL season contributed ₹11.5 billion (US dollar 182 million) to the GDP of the Indian economy.**
#
# There have been eleven seasons of the IPL tournament. The current IPL title holders are the Chennai Super Kings, who won the 2018 season. The most successful franchises in the tournament are the **Chennai Super Kings** and **Mumbai Indians** with 3 tournament wins each. **(*Source: Wikipedia)**

# %% [markdown]
# <a id=section2></a>
# ### 2. Load the packages and data

# %%
 # Import packages
import numpy as np
import pandas as pd
import seaborn as sns
import pandas_profiling
import matplotlib as mat
import matplotlib.pyplot as plt
import bokeh
# Out:
# C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_profiling\plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\asyncio\base_events.py", line 523, in run_forever
#     self._run_once()
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\asyncio\base_events.py", line 1758, in _run_once
#     handle._run()
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2901, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-9b8399f76169>", line 4, in <module>
#     import seaborn as sns
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\__init__.py", line 6, in <module>
#     from .rcmod import *
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\rcmod.py", line 5, in <module>
#     from . import palettes, _orig_rc_params
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\palettes.py", line 12, in <module>
#     from .utils import desaturate, set_hls_values, get_color_cycle
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\utils.py", line 11, in <module>
#     import matplotlib.pyplot as plt
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\backends\__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use(BACKEND)

# %% [markdown]
# #### Importing the Dataset

# %%
ipl = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/matches.csv')
ipl# Importing ipl dataset using pd.read_csv
# Out:
#        id  season       city        date                        team1  \
# 0       1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1       2    2017       Pune  2017-04-06               Mumbai Indians
# 2       3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3       4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4       5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5       6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6       7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7       8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8       9    2017       Pune  2017-04-11             Delhi Daredevils
# 9      10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 10     11    2017    Kolkata  2017-04-13              Kings XI Punjab
# 11     12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 12     13    2017     Rajkot  2017-04-14       Rising Pune Supergiant
# 13     14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14     15    2017      Delhi  2017-04-15             Delhi Daredevils
# 15     16    2017     Mumbai  2017-04-16                Gujarat Lions
# 16     17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 17     18    2017      Delhi  2017-04-17             Delhi Daredevils
# 18     19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 19     20    2017     Rajkot  2017-04-18  Royal Challengers Bangalore
# 20     21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 21     22    2017     Indore  2017-04-20              Kings XI Punjab
# 22     23    2017    Kolkata  2017-04-21        Kolkata Knight Riders
# 23     24    2017     Mumbai  2017-04-22               Mumbai Indians
# 24     25    2017       Pune  2017-04-22          Sunrisers Hyderabad
# 25     26    2017     Rajkot  2017-04-23              Kings XI Punjab
# 26     27    2017    Kolkata  2017-04-23        Kolkata Knight Riders
# 27     28    2017     Mumbai  2017-04-24       Rising Pune Supergiant
# 28     29    2017       Pune  2017-04-26       Rising Pune Supergiant
# 29     30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# ..    ...     ...        ...         ...                          ...
# 666  7924    2018  Bengaluru    01/05/18  Royal Challengers Bangalore
# 667  7925    2018      Delhi    02/05/18             Delhi Daredevils
# 668  7926    2018    Kolkata    03/05/18          Chennai Super Kings
# 669  7927    2018     Indore    04/05/18              Kings XI Punjab
# 670  7928    2018       Pune    05/05/18  Royal Challengers Bangalore
# 671  7929    2018  Hyderabad    05/05/18             Delhi Daredevils
# 672  7930    2018     Mumbai    06/05/18               Mumbai Indians
# 673  7931    2018     Indore    06/05/18             Rajasthan Royals
# 674  7932    2018  Hyderabad    07/05/18          Sunrisers Hyderabad
# 675  7933    2018     Jaipur    08/05/18             Rajasthan Royals
# 676  7934    2018    Kolkata    09/05/18               Mumbai Indians
# 677  7935    2018      Delhi    10/05/18             Delhi Daredevils
# 678  7936    2018     Jaipur    11/05/18          Chennai Super Kings
# 679  7937    2018     Indore    12/05/18        Kolkata Knight Riders
# 680  7938    2018      Delhi    12/05/18             Delhi Daredevils
# 681  7939    2018       Pune    13/05/18          Sunrisers Hyderabad
# 682  7940    2018     Mumbai    13/05/18               Mumbai Indians
# 683  7941    2018     Indore    14/05/18              Kings XI Punjab
# 684  7942    2018    Kolkata    15/05/18             Rajasthan Royals
# 685  7943    2018     Mumbai    16/05/18               Mumbai Indians
# 686  7944    2018  Bengaluru    17/05/18  Royal Challengers Bangalore
# 687  7945    2018      Delhi    18/05/18             Delhi Daredevils
# 688  7946    2018     Jaipur    19/05/18             Rajasthan Royals
# 689  7947    2018  Hyderabad    19/05/18          Sunrisers Hyderabad
# 690  7948    2018      Delhi    20/05/18             Delhi Daredevils
# 691  7949    2018       Pune    20/05/18              Kings XI Punjab
# 692  7950    2018     Mumbai    22/05/18          Sunrisers Hyderabad
# 693  7951    2018    Kolkata    23/05/18        Kolkata Knight Riders
# 694  7952    2018    Kolkata    25/05/18          Sunrisers Hyderabad
# 695  7953    2018     Mumbai    27/05/18          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# 2          Kolkata Knight Riders        Kolkata Knight Riders         field
# 3                Kings XI Punjab              Kings XI Punjab         field
# 4               Delhi Daredevils  Royal Challengers Bangalore           bat
# 5            Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 6                 Mumbai Indians               Mumbai Indians         field
# 7                Kings XI Punjab  Royal Challengers Bangalore           bat
# 8         Rising Pune Supergiant       Rising Pune Supergiant         field
# 9                 Mumbai Indians               Mumbai Indians         field
# 10         Kolkata Knight Riders        Kolkata Knight Riders         field
# 11                Mumbai Indians               Mumbai Indians         field
# 12                 Gujarat Lions                Gujarat Lions         field
# 13           Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14               Kings XI Punjab             Delhi Daredevils           bat
# 15                Mumbai Indians               Mumbai Indians         field
# 16   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 17         Kolkata Knight Riders             Delhi Daredevils           bat
# 18               Kings XI Punjab              Kings XI Punjab         field
# 19                 Gujarat Lions                Gujarat Lions         field
# 20              Delhi Daredevils          Sunrisers Hyderabad           bat
# 21                Mumbai Indians               Mumbai Indians         field
# 22                 Gujarat Lions                Gujarat Lions         field
# 23              Delhi Daredevils             Delhi Daredevils         field
# 24        Rising Pune Supergiant       Rising Pune Supergiant         field
# 25                 Gujarat Lions                Gujarat Lions         field
# 26   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 27                Mumbai Indians               Mumbai Indians         field
# 28         Kolkata Knight Riders        Kolkata Knight Riders         field
# 29                 Gujarat Lions                Gujarat Lions         field
# ..                           ...                          ...           ...
# 666               Mumbai Indians               Mumbai Indians         field
# 667             Rajasthan Royals             Rajasthan Royals         field
# 668        Kolkata Knight Riders        Kolkata Knight Riders         field
# 669               Mumbai Indians               Mumbai Indians         field
# 670          Chennai Super Kings          Chennai Super Kings         field
# 671          Sunrisers Hyderabad             Delhi Daredevils           bat
# 672        Kolkata Knight Riders        Kolkata Knight Riders         field
# 673              Kings XI Punjab              Kings XI Punjab         field
# 674  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 675              Kings XI Punjab             Rajasthan Royals           bat
# 676        Kolkata Knight Riders        Kolkata Knight Riders         field
# 677          Sunrisers Hyderabad             Delhi Daredevils           bat
# 678             Rajasthan Royals          Chennai Super Kings           bat
# 679              Kings XI Punjab              Kings XI Punjab         field
# 680  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 681          Chennai Super Kings          Chennai Super Kings         field
# 682             Rajasthan Royals             Rajasthan Royals         field
# 683  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 684        Kolkata Knight Riders        Kolkata Knight Riders         field
# 685              Kings XI Punjab              Kings XI Punjab         field
# 686          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 687          Chennai Super Kings          Chennai Super Kings         field
# 688  Royal Challengers Bangalore             Rajasthan Royals           bat
# 689        Kolkata Knight Riders          Sunrisers Hyderabad           bat
# 690               Mumbai Indians             Delhi Daredevils           bat
# 691          Chennai Super Kings          Chennai Super Kings         field
# 692          Chennai Super Kings          Chennai Super Kings         field
# 693             Rajasthan Royals             Rajasthan Royals         field
# 694        Kolkata Knight Riders        Kolkata Knight Riders         field
# 695          Chennai Super Kings          Chennai Super Kings         field
#
#      result  dl_applied                       winner  win_by_runs  \
# 0    normal           0          Sunrisers Hyderabad           35
# 1    normal           0       Rising Pune Supergiant            0
# 2    normal           0        Kolkata Knight Riders            0
# 3    normal           0              Kings XI Punjab            0
# 4    normal           0  Royal Challengers Bangalore           15
# 5    normal           0          Sunrisers Hyderabad            0
# 6    normal           0               Mumbai Indians            0
# 7    normal           0              Kings XI Punjab            0
# 8    normal           0             Delhi Daredevils           97
# 9    normal           0               Mumbai Indians            0
# 10   normal           0        Kolkata Knight Riders            0
# 11   normal           0               Mumbai Indians            0
# 12   normal           0                Gujarat Lions            0
# 13   normal           0        Kolkata Knight Riders           17
# 14   normal           0             Delhi Daredevils           51
# 15   normal           0               Mumbai Indians            0
# 16   normal           0       Rising Pune Supergiant           27
# 17   normal           0        Kolkata Knight Riders            0
# 18   normal           0          Sunrisers Hyderabad            5
# 19   normal           0  Royal Challengers Bangalore           21
# 20   normal           0          Sunrisers Hyderabad           15
# 21   normal           0               Mumbai Indians            0
# 22   normal           0                Gujarat Lions            0
# 23   normal           0               Mumbai Indians           14
# 24   normal           0       Rising Pune Supergiant            0
# 25   normal           0              Kings XI Punjab           26
# 26   normal           0        Kolkata Knight Riders           82
# 27   normal           0       Rising Pune Supergiant            3
# 28   normal           0        Kolkata Knight Riders            0
# 29   normal           0                Gujarat Lions            0
# ..      ...         ...                          ...          ...
# 666  normal           0  Royal Challengers Bangalore           14
# 667  normal           1             Delhi Daredevils            4
# 668  normal           0        Kolkata Knight Riders            0
# 669  normal           0               Mumbai Indians            0
# 670  normal           0          Chennai Super Kings            0
# 671  normal           0          Sunrisers Hyderabad            0
# 672  normal           0               Mumbai Indians           13
# 673  normal           0              Kings XI Punjab            0
# 674  normal           0          Sunrisers Hyderabad            5
# 675  normal           0             Rajasthan Royals           15
# 676  normal           0               Mumbai Indians          102
# 677  normal           0          Sunrisers Hyderabad            0
# 678  normal           0             Rajasthan Royals            0
# 679  normal           0        Kolkata Knight Riders           31
# 680  normal           0  Royal Challengers Bangalore            0
# 681  normal           0          Chennai Super Kings            0
# 682  normal           0             Rajasthan Royals            0
# 683  normal           0  Royal Challengers Bangalore            0
# 684  normal           0        Kolkata Knight Riders            0
# 685  normal           0               Mumbai Indians            3
# 686  normal           0  Royal Challengers Bangalore           14
# 687  normal           0             Delhi Daredevils           34
# 688  normal           0             Rajasthan Royals           30
# 689  normal           0        Kolkata Knight Riders            0
# 690  normal           0             Delhi Daredevils           11
# 691  normal           0          Chennai Super Kings            0
# 692  normal           0          Chennai Super Kings            0
# 693  normal           0        Kolkata Knight Riders           25
# 694  normal           0          Sunrisers Hyderabad           14
# 695  normal           0          Chennai Super Kings            0
#
#      win_by_wickets  player_of_match  \
# 0                 0     Yuvraj Singh
# 1                 7        SPD Smith
# 2                10          CA Lynn
# 3                 6       GJ Maxwell
# 4                 0        KM Jadhav
# 5                 9      Rashid Khan
# 6                 4           N Rana
# 7                 8         AR Patel
# 8                 0        SV Samson
# 9                 4        JJ Bumrah
# 10                8        SP Narine
# 11                4       KA Pollard
# 12                7           AJ Tye
# 13                0       RV Uthappa
# 14                0      CJ Anderson
# 15                6           N Rana
# 16                0        BA Stokes
# 17                4  NM Coulter-Nile
# 18                0          B Kumar
# 19                0         CH Gayle
# 20                0    KS Williamson
# 21                8       JC Buttler
# 22                4         SK Raina
# 23                0   MJ McClenaghan
# 24                6         MS Dhoni
# 25                0          HM Amla
# 26                0  NM Coulter-Nile
# 27                0        BA Stokes
# 28                7       RV Uthappa
# 29                7           AJ Tye
# ..              ...              ...
# 666               0       TG Southee
# 667               0          RR Pant
# 668               6        SP Narine
# 669               6         AS Yadav
# 670               6        RA Jadeja
# 671               7      Rashid Khan
# 672               0        HH Pandya
# 673               6      M Ur Rahman
# 674               0    KS Williamson
# 675               0       JC Buttler
# 676               0     Ishan Kishan
# 677               9         S Dhawan
# 678               4       JC Buttler
# 679               0        SP Narine
# 680               5   AB de Villiers
# 681               8        AT Rayudu
# 682               7       JC Buttler
# 683              10         UT Yadav
# 684               6    Kuldeep Yadav
# 685               0        JJ Bumrah
# 686               0   AB de Villiers
# 687               0         HV Patel
# 688               0          S Gopal
# 689               5          CA Lynn
# 690               0         A Mishra
# 691               5          L Ngidi
# 692               2     F du Plessis
# 693               0       AD Russell
# 694               0      Rashid Khan
# 695               8        SR Watson
#
#                                          venue                umpire1  \
# 0    Rajiv Gandhi International Stadium, Uppal            AY Dandekar
# 1      Maharashtra Cricket Association Stadium         A Nand Kishore
# 2       Saurashtra Cricket Association Stadium            Nitin Menon
# 3                       Holkar Cricket Stadium           AK Chaudhary
# 4                        M Chinnaswamy Stadium                    NaN
# 5    Rajiv Gandhi International Stadium, Uppal             A Deshmukh
# 6                             Wankhede Stadium            Nitin Menon
# 7                       Holkar Cricket Stadium           AK Chaudhary
# 8      Maharashtra Cricket Association Stadium            AY Dandekar
# 9                             Wankhede Stadium            Nitin Menon
# 10                                Eden Gardens             A Deshmukh
# 11                       M Chinnaswamy Stadium  KN Ananthapadmanabhan
# 12      Saurashtra Cricket Association Stadium         A Nand Kishore
# 13                                Eden Gardens            AY Dandekar
# 14                            Feroz Shah Kotla               YC Barde
# 15                            Wankhede Stadium         A Nand Kishore
# 16                       M Chinnaswamy Stadium  KN Ananthapadmanabhan
# 17                            Feroz Shah Kotla            Nitin Menon
# 18   Rajiv Gandhi International Stadium, Uppal            AY Dandekar
# 19      Saurashtra Cricket Association Stadium                 S Ravi
# 20   Rajiv Gandhi International Stadium, Uppal            CB Gaffaney
# 21                      Holkar Cricket Stadium              M Erasmus
# 22                                Eden Gardens            CB Gaffaney
# 23                            Wankhede Stadium         A Nand Kishore
# 24     Maharashtra Cricket Association Stadium            AY Dandekar
# 25      Saurashtra Cricket Association Stadium           AK Chaudhary
# 26                                Eden Gardens            CB Gaffaney
# 27                            Wankhede Stadium         A Nand Kishore
# 28     Maharashtra Cricket Association Stadium            AY Dandekar
# 29                       M Chinnaswamy Stadium           AK Chaudhary
# ..                                         ...                    ...
# 666                      M Chinnaswamy Stadium         Marais Erasmus
# 667                           Feroz Shah Kotla               O Nandan
# 668                               Eden Gardens       Kumar Dharmasena
# 669                     Holkar Cricket Stadium                 S Ravi
# 670    Maharashtra Cricket Association Stadium            Nitin Menon
# 671  Rajiv Gandhi International Stadium, Uppal         Bruce Oxenford
# 672                           Wankhede Stadium       Kumar Dharmasena
# 673                     Holkar Cricket Stadium          C Shamshuddin
# 674  Rajiv Gandhi International Stadium, Uppal         Bruce Oxenford
# 675                     Sawai Mansingh Stadium         Marais Erasmus
# 676                               Eden Gardens         Anil Chaudhary
# 677                           Feroz Shah Kotla          C Shamshuddin
# 678                     Sawai Mansingh Stadium         Marais Erasmus
# 679                     Holkar Cricket Stadium               O Nandan
# 680                           Feroz Shah Kotla       Kumar Dharmasena
# 681    Maharashtra Cricket Association Stadium         Marais Erasmus
# 682                           Wankhede Stadium            Nitin Menon
# 683                     Holkar Cricket Stadium         Bruce Oxenford
# 684                               Eden Gardens       Kumar Dharmasena
# 685                           Wankhede Stadium         Marais Erasmus
# 686                      M Chinnaswamy Stadium                 S Ravi
# 687                           Feroz Shah Kotla       Kumar Dharmasena
# 688                     Sawai Mansingh Stadium         Bruce Oxenford
# 689  Rajiv Gandhi International Stadium, Uppal         Anil Chaudhary
# 690                           Feroz Shah Kotla       Kumar Dharmasena
# 691    Maharashtra Cricket Association Stadium            Nitin Menon
# 692                           Wankhede Stadium         Marais Erasmus
# 693                               Eden Gardens            Nitin Menon
# 694                               Eden Gardens            Nitin Menon
# 695                           Wankhede Stadium         Marais Erasmus
#
#                    umpire2                umpire3
# 0                 NJ Llong                    NaN
# 1                   S Ravi                    NaN
# 2                CK Nandan                    NaN
# 3            C Shamshuddin                    NaN
# 4                      NaN                    NaN
# 5                 NJ Llong                    NaN
# 6                CK Nandan                    NaN
# 7            C Shamshuddin                    NaN
# 8                   S Ravi                    NaN
# 9                CK Nandan                    NaN
# 10                NJ Llong                    NaN
# 11            AK Chaudhary                    NaN
# 12                  S Ravi                    NaN
# 13                NJ Llong                    NaN
# 14             Nitin Menon                    NaN
# 15                  S Ravi                    NaN
# 16           C Shamshuddin                    NaN
# 17               CK Nandan                    NaN
# 18              A Deshmukh                    NaN
# 19               VK Sharma                    NaN
# 20                NJ Llong                    NaN
# 21           C Shamshuddin                    NaN
# 22             Nitin Menon                    NaN
# 23                  S Ravi                    NaN
# 24              A Deshmukh                    NaN
# 25               M Erasmus                    NaN
# 26               CK Nandan                    NaN
# 27                  S Ravi                    NaN
# 28                NJ Llong                    NaN
# 29           C Shamshuddin                    NaN
# ..                     ...                    ...
# 666            Nitin Menon         Yeshwant Barde
# 667  Virender Kumar Sharma         Bruce Oxenford
# 668           A.D Deshmukh         Anil Chaudhary
# 669          Anil Dandekar          C Shamshuddin
# 670         Yeshwant Barde         Marais Erasmus
# 671               O Nandan  Virender Kumar Sharma
# 672           A.D Deshmukh         Anil Chaudhary
# 673                 S Ravi          Anil Dandekar
# 674  Virender Kumar Sharma               O Nandan
# 675            Nitin Menon         Yeshwant Barde
# 676   K Ananthapadmanabhan       Kumar Dharmasena
# 677          Anil Dandekar                 S Ravi
# 678         Yeshwant Barde            Nitin Menon
# 679  Virender Kumar Sharma         Bruce Oxenford
# 680         Anil Chaudhary   K Ananthapadmanabhan
# 681         Yeshwant Barde          Anil Dandekar
# 682                 S Ravi          C Shamshuddin
# 683  Virender Kumar Sharma               O Nandan
# 684         Anil Chaudhary        Vineet Kulkarni
# 685            Nitin Menon         Yeshwant Barde
# 686          Anil Dandekar          C Shamshuddin
# 687        Vineet Kulkarni               O Nandan
# 688  Virender Kumar Sharma          C Shamshuddin
# 689                 S Ravi          Anil Dandekar
# 690               O Nandan        Vineet Kulkarni
# 691         Yeshwant Barde         Marais Erasmus
# 692          C Shamshuddin                 S Ravi
# 693         Anil Chaudhary       Kumar Dharmasena
# 694       Kumar Dharmasena         Anil Chaudhary
# 695                 S Ravi            Nitin Menon
#
# [696 rows x 18 columns]

# %% [markdown]
# - The dataset consists of the information about IPL tournament held in India during month of April - May. Various variables present in the dataset includes data of teams, venues, toss winers, winners etc.
# - The dataset comprises of __696 observations of 18 columns__.

# %% [markdown]
# | Column Name     | Description                                               |
# | -------------   |:-------------                                            :|
# | season          | Year when tournament is held                              |
# | city            | In which city match was played                            |
# | Date            | Match date                                                |
# | team1           | First team name                                           |
# | team2           | Second team name                                          |
# | toss_winner     | Which team won the toss                                   |
# | toss_decision   | Number of sibling and/or spouse travelling with passenger |
# | result          | Number of parent and/or children travelling with passenger|
# | dl_applied      | Duckworth–Lewis method used for results                   |
# | winner          | Which team won the match                                  |
# | win_by_runs     | which team defended the total                             |
# | win_by_wickets  | Which team chase the traget                               |
# | player_of_match | Which player played the best to contribute more to win    |
# | venue           | On which ground match was played                          |
# | umpire1         | First standing Umpire name                                |
# | umpire2         | Second standing Umpire name                               |
# | umpire3         | Third Umpire name                                         |

# %% [markdown]
# <a id=section3></a>

# %% [markdown]
# ## 3. Data Profiling

# %% [markdown]
# - In the upcoming sections we will first __understand our dataset__ using various pandas functionalities.
# - Then with the help of __pandas profiling__ we will find which columns of our dataset need preprocessing.
# - In __preprocessing__ we will deal with erronous and missing values of columns.
# - Again we will do __pandas profiling__ to see how preprocessing have transformed our dataset.

# %% [markdown]
# <a id=section301></a>

# %% [markdown]
# ### 3.1 Understanding the Dataset

# %%
ipl.shape                                       # This will print the number of rows and columns of the Data Frame
# Out:
# (696, 18)

# %% [markdown]
# IPL data has __891 rows__ and __12 columns.__

# %%
ipl.info()                                              # This will give Index, Datatype and Memory information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 18 columns):
# id                 696 non-null int64
# season             696 non-null int64
# city               689 non-null object
# date               696 non-null object
# team1              696 non-null object
# team2              696 non-null object
# toss_winner        696 non-null object
# toss_decision      696 non-null object
# result             696 non-null object
# dl_applied         696 non-null int64
# winner             693 non-null object
# win_by_runs        696 non-null int64
# win_by_wickets     696 non-null int64
# player_of_match    693 non-null object
# venue              696 non-null object
# umpire1            695 non-null object
# umpire2            695 non-null object
# umpire3            60 non-null object
# dtypes: int64(5), object(13)
# memory usage: 98.0+ KB

# %%
ipl.count()                                     # This will show missing values in each columns
# Out:
# id                 696
# season             696
# city               689
# date               696
# team1              696
# team2              696
# toss_winner        696
# toss_decision      696
# result             696
# dl_applied         696
# winner             693
# win_by_runs        696
# win_by_wickets     696
# player_of_match    693
# venue              696
# umpire1            695
# umpire2            695
# umpire3             60
# dtype: int64

# %%
ipl.index                                         #This will show start & stop point of Index
# Out:
# RangeIndex(start=0, stop=696, step=1)

# %%
ipl.columns                                       #This will show column's name
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl.head(10)                                    #This will show to 10 entries of the dataset
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
# 5          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 6               Mumbai Indians               Mumbai Indians         field
# 7              Kings XI Punjab  Royal Challengers Bangalore           bat
# 8       Rising Pune Supergiant       Rising Pune Supergiant         field
# 9               Mumbai Indians               Mumbai Indians         field
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# 1  normal           0       Rising Pune Supergiant            0
# 2  normal           0        Kolkata Knight Riders            0
# 3  normal           0              Kings XI Punjab            0
# 4  normal           0  Royal Challengers Bangalore           15
# 5  normal           0          Sunrisers Hyderabad            0
# 6  normal           0               Mumbai Indians            0
# 7  normal           0              Kings XI Punjab            0
# 8  normal           0             Delhi Daredevils           97
# 9  normal           0               Mumbai Indians            0
#
#    win_by_wickets player_of_match                                      venue  \
# 0               0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal
# 1               7       SPD Smith    Maharashtra Cricket Association Stadium
# 2              10         CA Lynn     Saurashtra Cricket Association Stadium
# 3               6      GJ Maxwell                     Holkar Cricket Stadium
# 4               0       KM Jadhav                      M Chinnaswamy Stadium
# 5               9     Rashid Khan  Rajiv Gandhi International Stadium, Uppal
# 6               4          N Rana                           Wankhede Stadium
# 7               8        AR Patel                     Holkar Cricket Stadium
# 8               0       SV Samson    Maharashtra Cricket Association Stadium
# 9               4       JJ Bumrah                           Wankhede Stadium
#
#           umpire1        umpire2 umpire3
# 0     AY Dandekar       NJ Llong     NaN
# 1  A Nand Kishore         S Ravi     NaN
# 2     Nitin Menon      CK Nandan     NaN
# 3    AK Chaudhary  C Shamshuddin     NaN
# 4             NaN            NaN     NaN
# 5      A Deshmukh       NJ Llong     NaN
# 6     Nitin Menon      CK Nandan     NaN
# 7    AK Chaudhary  C Shamshuddin     NaN
# 8     AY Dandekar         S Ravi     NaN
# 9     Nitin Menon      CK Nandan     NaN

# %%
ipl.describe(include = 'all')                 #This will show distribution of complete dataset
# Out:
#                  id       season    city        date           team1  \
# count    696.000000   696.000000     689         696             696
# unique          NaN          NaN      32         498              14
# top             NaN          NaN  Mumbai  2011-04-09  Mumbai Indians
# freq            NaN          NaN      94           2              91
# mean     974.103448  2012.965517     NaN         NaN             NaN
# std     2143.239623     3.069266     NaN         NaN             NaN
# min        1.000000  2008.000000     NaN         NaN             NaN
# 25%      174.750000  2010.000000     NaN         NaN             NaN
# 50%      348.500000  2013.000000     NaN         NaN             NaN
# 75%      522.250000  2016.000000     NaN         NaN             NaN
# max     7953.000000  2018.000000     NaN         NaN             NaN
#
#                               team2     toss_winner toss_decision  result  \
# count                           696             696           696     696
# unique                           14              14             2       3
# top     Royal Challengers Bangalore  Mumbai Indians         field  normal
# freq                             90              90           413     686
# mean                            NaN             NaN           NaN     NaN
# std                             NaN             NaN           NaN     NaN
# min                             NaN             NaN           NaN     NaN
# 25%                             NaN             NaN           NaN     NaN
# 50%                             NaN             NaN           NaN     NaN
# 75%                             NaN             NaN           NaN     NaN
# max                             NaN             NaN           NaN     NaN
#
#         dl_applied          winner  win_by_runs  win_by_wickets  \
# count   696.000000             693   696.000000      696.000000
# unique         NaN              14          NaN             NaN
# top            NaN  Mumbai Indians          NaN             NaN
# freq           NaN              98          NaN             NaN
# mean      0.027299             NaN    13.472701        3.349138
# std       0.163070             NaN    23.607994        3.411398
# min       0.000000             NaN     0.000000        0.000000
# 25%       0.000000             NaN     0.000000        0.000000
# 50%       0.000000             NaN     0.000000        3.000000
# 75%       0.000000             NaN    19.000000        6.000000
# max       1.000000             NaN   146.000000       10.000000
#
#        player_of_match                  venue          umpire1 umpire2  \
# count              693                    696              695     695
# unique             214                     35               55      58
# top           CH Gayle  M Chinnaswamy Stadium  HDPK Dharmasena  S Ravi
# freq                20                     73               73      56
# mean               NaN                    NaN              NaN     NaN
# std                NaN                    NaN              NaN     NaN
# min                NaN                    NaN              NaN     NaN
# 25%                NaN                    NaN              NaN     NaN
# 50%                NaN                    NaN              NaN     NaN
# 75%                NaN                    NaN              NaN     NaN
# max                NaN                    NaN              NaN     NaN
#
#               umpire3
# count              60
# unique             18
# top     C Shamshuddin
# freq                6
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
ipl.sample(10)                          # This will show random values from dataset
# Out:
#        id  season           city        date                team1  \
# 507   508    2014         Mumbai  2014-05-23       Mumbai Indians
# 530   531    2015  Visakhapatnam  2015-04-18     Delhi Daredevils
# 65     66    2008      Hyderabad  2008-04-22      Deccan Chargers
# 417   418    2013        Chennai  2013-04-28  Chennai Super Kings
# 404   405    2013      Hyderabad  2013-04-19      Kings XI Punjab
# 681  7939    2018           Pune    13/05/18  Sunrisers Hyderabad
# 399   400    2013     Chandigarh  2013-04-16      Kings XI Punjab
# 363   364    2012        Chennai  2012-05-12     Delhi Daredevils
# 572   573    2015         Mumbai  2015-05-19       Mumbai Indians
# 465   466    2014        Sharjah  2014-04-22      Kings XI Punjab
#
#                      team2            toss_winner toss_decision  result  \
# 507       Delhi Daredevils       Delhi Daredevils         field  normal
# 530    Sunrisers Hyderabad       Delhi Daredevils           bat  normal
# 65        Delhi Daredevils        Deccan Chargers           bat  normal
# 417  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 404    Sunrisers Hyderabad        Kings XI Punjab           bat  normal
# 681    Chennai Super Kings    Chennai Super Kings         field  normal
# 399  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 363    Chennai Super Kings    Chennai Super Kings         field  normal
# 572    Chennai Super Kings         Mumbai Indians           bat  normal
# 465    Sunrisers Hyderabad    Sunrisers Hyderabad         field  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 507           0       Mumbai Indians           15               0
# 530           0     Delhi Daredevils            4               0
# 65            0     Delhi Daredevils            0               9
# 417           0  Chennai Super Kings           14               0
# 404           0  Sunrisers Hyderabad            0               5
# 681           0  Chennai Super Kings            0               8
# 399           0      Kings XI Punjab            4               0
# 363           0  Chennai Super Kings            0               9
# 572           0       Mumbai Indians           25               0
# 465           0      Kings XI Punjab           72               0
#
#     player_of_match                                              venue  \
# 507      MEK Hussey                                   Wankhede Stadium
# 530       JP Duminy  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...
# 65         V Sehwag          Rajiv Gandhi International Stadium, Uppal
# 417      MEK Hussey                    MA Chidambaram Stadium, Chepauk
# 404       GH Vihari          Rajiv Gandhi International Stadium, Uppal
# 681       AT Rayudu            Maharashtra Cricket Association Stadium
# 399         MS Gony         Punjab Cricket Association Stadium, Mohali
# 363   BW Hilfenhaus                    MA Chidambaram Stadium, Chepauk
# 572      KA Pollard                                   Wankhede Stadium
# 465      GJ Maxwell                            Sharjah Cricket Stadium
#
#              umpire1         umpire2        umpire3
# 507           S Ravi       RJ Tucker            NaN
# 530        PG Pathak          S Ravi            NaN
# 65         IL Howell       AM Saheba            NaN
# 417        Aleem Dar      SJA Taufel            NaN
# 404  HDPK Dharmasena       CK Nandan            NaN
# 681   Marais Erasmus  Yeshwant Barde  Anil Dandekar
# 399        CK Nandan      SJA Taufel            NaN
# 363            S Das     BR Doctrove            NaN
# 572  HDPK Dharmasena  RK Illingworth            NaN
# 465        M Erasmus          S Ravi            NaN

# %%
ipl.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %% [markdown]
# From the above output we can see that umpire3 columns contains maximum null values.

# %% [markdown]
# <a id=section302></a>

# %% [markdown]
# ### 3.2 Pre Profiling

# %%
profile = pandas_profiling.ProfileReport(ipl)
profile.to_file(outputfile="ipl.html")

# %% [markdown]
# - By pandas profiling, an __interactive HTML report__ gets generated which contins all the information about the columns of the dataset, like the __counts and type__ of each _column_. Detailed information about each column, __coorelation between different columns__ and a sample of dataset.<br/>
# - It gives us __visual interpretation__ of each column in the data.
# - _Spread of the data_ can be better understood by the distribution plot.
# - _Grannular level_ analysis of each column.

# %% [markdown]
# Here, we have done Pandas Profiling before preprocessing our dataset, so we have named the html file as __ipl.html__.

# %% [markdown]
# <a id=section303></a>

# %% [markdown]
# ### 3.3 Preprocessing

# %% [markdown]
# - Dealing with missing values<br/>
#     - Dropping the column __'umpire3 & dl_applied'__ as it has too many _null_ & zero values.

# %%
ipl.drop(['umpire3', 'dl_applied'], axis=1, inplace=True)         #Deleting umpire3 & dl_applied columns

# %% [markdown]
# <a id=section304></a>

# %% [markdown]
# ## 3.4 Post Pandas Profiling

# %%
profile = pandas_profiling.ProfileReport(ipl)
profile.to_file(outputfile="ipl_postprofilling.html")

# %% [markdown]
# The pandas profiling report which we have generated after preprocessing will give us more beneficial insights. We can compare the two reports, i.e __ipl.html__ and ipl_postprofilling.html.<br/>
# In titanic_after_preprocessing.html report, observations:
# - In the Dataset info, Total __Missing(%)__ = __0.1%__
# - Number of __variables__ = __16__

# %% [markdown]
# <a id=section4></a>

# %% [markdown]
# ### 4. Questions

# %% [markdown]
# <a id=section401></a>

# %% [markdown]
# ### 4.1 How many seasons we’ve got in the dataset ?

# %%
ipl['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018],
#       dtype=int64)

# %% [markdown]
# We have got all the seasons __Starting from 2008 till last year i.e 2018.__ To know the exact count:

# %%
len(ipl['season'].unique())
# Out:
# 11

# %% [markdown]
# We have got total __11 seasons__.

# %% [markdown]
# <a id=section402></a>

# %% [markdown]
# ### 4.2 Which Team had won by maximum runs?

# %%
ipl.iloc[ipl['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# Name: 43, dtype: object

# %% [markdown]
# As of now all the match played in entire history of IPL, we have got a match which is played in 2017 season between **Mumbai Indians & Delhi Daredevils** where **Mumbai Indians defended the score & won the match by margin of 146 runs.**

# %% [markdown]
# <a id=section403></a>

# %% [markdown]
# ### 4.2 Which Team had won by maximum wicket?

# %%
ipl.iloc[ipl['win_by_wickets'].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# umpire2                                         CK Nandan
# Name: 2, dtype: object

# %% [markdown]
# As of now all the match played in entire history of IPL, we have got a match which is played in 2017 season between **Gujrat Lions & Kolkata Knight Riders** where **Kolkata Night Riders chased the score without lossing a wicket**.

# %% [markdown]
# <a id=section404></a>

# %% [markdown]
# ### 4.4 Which Season had most number of matches?

# %%
sns.countplot(x='season', data=ipl)
plt.show()

# %% [markdown]
# From the above graph we can see that in **the season of 2013 year total 76 matches** were played which is the most among all the season.

# %% [markdown]
# <a id=section405></a>

# %% [markdown]
# ### 4.5 Which IPL Team is more successful?

# %%
data = ipl.winner.value_counts()
sns.barplot(y = data.index, x = data, orient='h');

# %% [markdown]
# From the above grapth we can see that **Mumbai Indians** is most succesfull team among all the ipl team played in the history of IPL.

# %% [markdown]
# <a id=section406></a>

# %% [markdown]
# ### 4.6 Which player has won maximum player of the match award?

# %%
top_players = ipl.player_of_match.value_counts()[:10]
fig, ax = plt.subplots()
ax.set_ylim([0,20])
ax.set_ylabel("Count")
ax.set_title("Top player of the match Winners")
sns.barplot(x = top_players.index, y = top_players, orient='v'); #palette="Blues");
plt.show()

# %% [markdown]
# From the above graph we can see that **Chris Gayle** has won **maximum numbers of Player of The Match** awards

# %% [markdown]
# <a id=section407></a>

# %% [markdown]
# ### 4.7 Has Toss-winning helped in winning matches?

# %%
ss = ipl['toss_winner'] == ipl['winner']
ss.groupby(ss).size()
sns.countplot(ss);

# %% [markdown]
# This result shows us **Toss winning has not affected end match result** as result has shown almost same sount.

# %% [markdown]
# <a id=section408></a>

# %% [markdown]
# ### 4.8 IPL matches played in which stadiums?

# %%
ipl['venue'].unique()
# Out:
# array(['Rajiv Gandhi International Stadium, Uppal',
#        'Maharashtra Cricket Association Stadium',
#        'Saurashtra Cricket Association Stadium', 'Holkar Cricket Stadium',
#        'M Chinnaswamy Stadium', 'Wankhede Stadium', 'Eden Gardens',
#        'Feroz Shah Kotla',
#        'Punjab Cricket Association IS Bindra Stadium, Mohali',
#        'Green Park', 'Punjab Cricket Association Stadium, Mohali',
#        'Sawai Mansingh Stadium', 'MA Chidambaram Stadium, Chepauk',
#        'Dr DY Patil Sports Academy', 'Newlands', "St George's Park",
#        'Kingsmead', 'SuperSport Park', 'Buffalo Park',
#        'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
#        'Sharjah Cricket Stadium', 'Dubai International Cricket Stadium'],
#       dtype=object)

# %% [markdown]
# <a id=section409></a>

# %% [markdown]
# ### 4.9 Which Team is best in defending the total?

# %%
ipl[ipl['win_by_runs']>0].groupby(['winner'])['win_by_runs'].count().sort_values(ascending = False)
# Out:
# winner
# Mumbai Indians                 51
# Chennai Super Kings            49
# Kings XI Punjab                35
# Kolkata Knight Riders          34
# Royal Challengers Bangalore    32
# Sunrisers Hyderabad            28
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Rising Pune Supergiants         2
# Kochi Tuskers Kerala            2
# Gujarat Lions                   1
# Name: win_by_runs, dtype: int64

# %% [markdown]
# From the above result we can see that **Mumbai Indians has defended the total 51 times** which is most among all other teams, followed by **Chennai Super Kings 49** times & **Kings XI Punjab** 35 times.

# %%
#sns.barplot(x="day", y="total_bill", data=tips)
fig, ax = plt.subplots()
#fig.figsize = [16,10]
#ax.set_ylim([0,20])
ax.set_title("Winning by Runs - Team Performance")
#top_players.plot.bar()
sns.boxplot(y = 'winner', x = 'win_by_runs', data=ipl[ipl['win_by_runs']>0], orient = 'h'); #palette="Blues");
plt.show()

# %% [markdown]
# <a id=section410></a>

# %% [markdown]
# ### 4.10 Which Team is best in chasing the target?

# %%
ipl[ipl['win_by_wickets']>0].groupby(['winner'])['win_by_wickets'].count().sort_values(ascending = False)
# Out:
# winner
# Kolkata Knight Riders          52
# Royal Challengers Bangalore    46
# Mumbai Indians                 46
# Delhi Daredevils               42
# Rajasthan Royals               41
# Chennai Super Kings            41
# Kings XI Punjab                39
# Sunrisers Hyderabad            23
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: win_by_wickets, dtype: int64

# %% [markdown]
# From the above results we can see that **Kolkata Knight Riders as chased the traget 52 times** which is most by any team in IPL history, followed by **Royal Challengers Bangalore & Mumbai Indians 46 times each**.

# %%
#sns.barplot(x="day", y="total_bill", data=tips)
fig, ax = plt.subplots()
#fig.figsize = [16,10]
#ax.set_ylim([0,20])
ax.set_title("Winning by Wickets - Team Performance")
#top_players.plot.bar()
sns.boxplot(y = 'winner', x = 'win_by_wickets', data=ipl[ipl['win_by_wickets']>0], orient = 'h'); #palette="Blues");
plt.show()

# %% [markdown]
# <a id=section411></a>

# %% [markdown]
# ### 4.11 Which is the best venue to defend the total?

# %%
venue_by_runs=ipl[ipl['win_by_runs']>0].groupby(['venue'])['win_by_runs'].count().sort_values(ascending = False)
venue_by_runs
# Out:
# venue
# Wankhede Stadium                                        33
# Feroz Shah Kotla                                        33
# M Chinnaswamy Stadium                                   30
# MA Chidambaram Stadium, Chepauk                         30
# Eden Gardens                                            29
# Rajiv Gandhi International Stadium, Uppal               23
# Punjab Cricket Association Stadium, Mohali              15
# Sawai Mansingh Stadium                                  14
# Subrata Roy Sahara Stadium                              11
# Kingsmead                                                9
# Dr DY Patil Sports Academy                               7
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium      7
# Maharashtra Cricket Association Stadium                  7
# Punjab Cricket Association IS Bindra Stadium, Mohali     7
# Sardar Patel Stadium, Motera                             6
# Brabourne Stadium                                        6
# Himachal Pradesh Cricket Association Stadium             5
# Barabati Stadium                                         4
# Newlands                                                 4
# SuperSport Park                                          4
# New Wanderers Stadium                                    3
# Saurashtra Cricket Association Stadium                   3
# Dubai International Cricket Stadium                      3
# Sheikh Zayed Stadium                                     3
# St George's Park                                         3
# Nehru Stadium                                            3
# Vidarbha Cricket Association Stadium, Jamtha             2
# JSCA International Stadium Complex                       2
# Shaheed Veer Narayan Singh International Stadium         2
# Sharjah Cricket Stadium                                  2
# Buffalo Park                                             2
# OUTsurance Oval                                          1
# Holkar Cricket Stadium                                   1
# De Beers Diamond Oval                                    1
# Name: win_by_runs, dtype: int64

# %%
plt.figure(figsize=(5,12))
sns.swarmplot(x='win_by_runs',y='venue',data=ipl)
plt.show()

# %% [markdown]
# **Wankhede Stadium** and **Feroz Shah Kotla** are the best venue to defend the total.

# %% [markdown]
# <a id=section412></a>

# %% [markdown]
# ### 4.12 Which is the best venue to chase the total?

# %%
venue_by_wickets=ipl[ipl['win_by_wickets']>0].groupby(['venue'])['win_by_wickets'].count().sort_values(ascending = False)
venue_by_wickets
# Out:
# venue
# Eden Gardens                                            41
# M Chinnaswamy Stadium                                   40
# Wankhede Stadium                                        33
# Feroz Shah Kotla                                        33
# Rajiv Gandhi International Stadium, Uppal               32
# Sawai Mansingh Stadium                                  26
# Punjab Cricket Association Stadium, Mohali              20
# MA Chidambaram Stadium, Chepauk                         18
# Maharashtra Cricket Association Stadium                 14
# Dr DY Patil Sports Academy                              10
# SuperSport Park                                          8
# Holkar Cricket Stadium                                   8
# Punjab Cricket Association IS Bindra Stadium, Mohali     7
# Subrata Roy Sahara Stadium                               6
# Saurashtra Cricket Association Stadium                   6
# Kingsmead                                                6
# JSCA International Stadium Complex                       5
# Brabourne Stadium                                        5
# New Wanderers Stadium                                    5
# Sardar Patel Stadium, Motera                             5
# Himachal Pradesh Cricket Association Stadium             4
# Green Park                                               4
# St George's Park                                         4
# Dubai International Cricket Stadium                      4
# Shaheed Veer Narayan Singh International Stadium         4
# Sharjah Cricket Stadium                                  4
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium      4
# Barabati Stadium                                         3
# Sheikh Zayed Stadium                                     3
# Newlands                                                 2
# De Beers Diamond Oval                                    2
# Nehru Stadium                                            2
# Vidarbha Cricket Association Stadium, Jamtha             1
# OUTsurance Oval                                          1
# Buffalo Park                                             1
# Name: win_by_wickets, dtype: int64

# %%
plt.figure(figsize=(5,12))
sns.swarmplot(x='win_by_wickets',y='venue',data=ipl)
plt.show()

# %% [markdown]
# **Eden Gardens** is the best venue for chasing

# %% [markdown]
# <a id=section413></a>

# %% [markdown]
# ### 4.13 Venue wise result!

# %%
venue_details=pd.concat([venue_by_runs, venue_by_wickets], axis=1)
venue_details
# Out:
# C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                                                     win_by_runs  \
# Barabati Stadium                                            4.0
# Brabourne Stadium                                           6.0
# Buffalo Park                                                2.0
# De Beers Diamond Oval                                       1.0
# Dr DY Patil Sports Academy                                  7.0
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...          7.0
# Dubai International Cricket Stadium                         3.0
# Eden Gardens                                               29.0
# Feroz Shah Kotla                                           33.0
# Green Park                                                  NaN
# Himachal Pradesh Cricket Association Stadium                5.0
# Holkar Cricket Stadium                                      1.0
# JSCA International Stadium Complex                          2.0
# Kingsmead                                                   9.0
# M Chinnaswamy Stadium                                      30.0
# MA Chidambaram Stadium, Chepauk                            30.0
# Maharashtra Cricket Association Stadium                     7.0
# Nehru Stadium                                               3.0
# New Wanderers Stadium                                       3.0
# Newlands                                                    4.0
# OUTsurance Oval                                             1.0
# Punjab Cricket Association IS Bindra Stadium, M...          7.0
# Punjab Cricket Association Stadium, Mohali                 15.0
# Rajiv Gandhi International Stadium, Uppal                  23.0
# Sardar Patel Stadium, Motera                                6.0
# Saurashtra Cricket Association Stadium                      3.0
# Sawai Mansingh Stadium                                     14.0
# Shaheed Veer Narayan Singh International Stadium            2.0
# Sharjah Cricket Stadium                                     2.0
# Sheikh Zayed Stadium                                        3.0
# St George's Park                                            3.0
# Subrata Roy Sahara Stadium                                 11.0
# SuperSport Park                                             4.0
# Vidarbha Cricket Association Stadium, Jamtha                2.0
# Wankhede Stadium                                           33.0
#
#                                                     win_by_wickets
# Barabati Stadium                                                 3
# Brabourne Stadium                                                5
# Buffalo Park                                                     1
# De Beers Diamond Oval                                            2
# Dr DY Patil Sports Academy                                      10
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...               4
# Dubai International Cricket Stadium                              4
# Eden Gardens                                                    41
# Feroz Shah Kotla                                                33
# Green Park                                                       4
# Himachal Pradesh Cricket Association Stadium                     4
# Holkar Cricket Stadium                                           8
# JSCA International Stadium Complex                               5
# Kingsmead                                                        6
# M Chinnaswamy Stadium                                           40
# MA Chidambaram Stadium, Chepauk                                 18
# Maharashtra Cricket Association Stadium                         14
# Nehru Stadium                                                    2
# New Wanderers Stadium                                            5
# Newlands                                                         2
# OUTsurance Oval                                                  1
# Punjab Cricket Association IS Bindra Stadium, M...               7
# Punjab Cricket Association Stadium, Mohali                      20
# Rajiv Gandhi International Stadium, Uppal                       32
# Sardar Patel Stadium, Motera                                     5
# Saurashtra Cricket Association Stadium                           6
# Sawai Mansingh Stadium                                          26
# Shaheed Veer Narayan Singh International Stadium                 4
# Sharjah Cricket Stadium                                          4
# Sheikh Zayed Stadium                                             3
# St George's Park                                                 4
# Subrata Roy Sahara Stadium                                       6
# SuperSport Park                                                  8
# Vidarbha Cricket Association Stadium, Jamtha                     1
# Wankhede Stadium                                                33

# %%
print(venue_details.dtypes)
# Out:
# win_by_runs       float64
# win_by_wickets      int64
# dtype: object

# %%
venue_details['win_by_runs'] = venue_details['win_by_runs'].fillna(0.0).astype(int) 
venue_details
# Out:
#                                                     win_by_runs  \
# Barabati Stadium                                              4
# Brabourne Stadium                                             6
# Buffalo Park                                                  2
# De Beers Diamond Oval                                         1
# Dr DY Patil Sports Academy                                    7
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...            7
# Dubai International Cricket Stadium                           3
# Eden Gardens                                                 29
# Feroz Shah Kotla                                             33
# Green Park                                                    0
# Himachal Pradesh Cricket Association Stadium                  5
# Holkar Cricket Stadium                                        1
# JSCA International Stadium Complex                            2
# Kingsmead                                                     9
# M Chinnaswamy Stadium                                        30
# MA Chidambaram Stadium, Chepauk                              30
# Maharashtra Cricket Association Stadium                       7
# Nehru Stadium                                                 3
# New Wanderers Stadium                                         3
# Newlands                                                      4
# OUTsurance Oval                                               1
# Punjab Cricket Association IS Bindra Stadium, M...            7
# Punjab Cricket Association Stadium, Mohali                   15
# Rajiv Gandhi International Stadium, Uppal                    23
# Sardar Patel Stadium, Motera                                  6
# Saurashtra Cricket Association Stadium                        3
# Sawai Mansingh Stadium                                       14
# Shaheed Veer Narayan Singh International Stadium              2
# Sharjah Cricket Stadium                                       2
# Sheikh Zayed Stadium                                          3
# St George's Park                                              3
# Subrata Roy Sahara Stadium                                   11
# SuperSport Park                                               4
# Vidarbha Cricket Association Stadium, Jamtha                  2
# Wankhede Stadium                                             33
#
#                                                     win_by_wickets
# Barabati Stadium                                                 3
# Brabourne Stadium                                                5
# Buffalo Park                                                     1
# De Beers Diamond Oval                                            2
# Dr DY Patil Sports Academy                                      10
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...               4
# Dubai International Cricket Stadium                              4
# Eden Gardens                                                    41
# Feroz Shah Kotla                                                33
# Green Park                                                       4
# Himachal Pradesh Cricket Association Stadium                     4
# Holkar Cricket Stadium                                           8
# JSCA International Stadium Complex                               5
# Kingsmead                                                        6
# M Chinnaswamy Stadium                                           40
# MA Chidambaram Stadium, Chepauk                                 18
# Maharashtra Cricket Association Stadium                         14
# Nehru Stadium                                                    2
# New Wanderers Stadium                                            5
# Newlands                                                         2
# OUTsurance Oval                                                  1
# Punjab Cricket Association IS Bindra Stadium, M...               7
# Punjab Cricket Association Stadium, Mohali                      20
# Rajiv Gandhi International Stadium, Uppal                       32
# Sardar Patel Stadium, Motera                                     5
# Saurashtra Cricket Association Stadium                           6
# Sawai Mansingh Stadium                                          26
# Shaheed Veer Narayan Singh International Stadium                 4
# Sharjah Cricket Stadium                                          4
# Sheikh Zayed Stadium                                             3
# St George's Park                                                 4
# Subrata Roy Sahara Stadium                                       6
# SuperSport Park                                                  8
# Vidarbha Cricket Association Stadium, Jamtha                     1
# Wankhede Stadium                                                33

# %% [markdown]
# <a id=section414></a>

# %% [markdown]
# ### 4.14 Which player received the maximum number of Player of Match award while defending the total?

# %%
MOM_runs=ipl[ipl['win_by_runs']>2].groupby(['player_of_match'])['win_by_runs'].count().sort_values(ascending = False)
MOM_runs
# Out:
# player_of_match
# AB de Villiers     11
# CH Gayle           10
# SK Raina            9
# DA Warner           8
# MEK Hussey          8
# MS Dhoni            7
# RG Sharma           7
# KA Pollard          7
# A Mishra            6
# AT Rayudu           5
# SR Tendulkar        5
# SR Watson           5
# SC Ganguly          5
# AM Rahane           5
# SV Samson           4
# RA Jadeja           4
# KC Sangakkara       4
# YK Pathan           4
# M Vijay             4
# G Gambhir           3
# JP Duminy           3
# KS Williamson       3
# RV Uthappa          3
# Rashid Khan         3
# Harbhajan Singh     3
# Yuvraj Singh        3
# Sandeep Sharma      3
# SP Narine           3
# BB McCullum         3
# V Kohli             3
#                    ..
# NM Coulter-Nile     1
# N Rana              1
# KH Pandya           1
# KK Nair             1
# KMDN Kulasekara     1
# R Sharma            1
# MP Stoinis          1
# MN Samuels          1
# LH Ferguson         1
# LJ Wright           1
# MM Sharma           1
# M Ntini             1
# JJ Bumrah           1
# P Kumar             1
# JC Buttler          1
# PD Collingwood      1
# Ishan Kishan        1
# Iqbal Abdulla       1
# IK Pathan           1
# I Sharma            1
# Harmeet Singh       1
# PP Ojha             1
# HM Amla             1
# PV Tambe            1
# R Bhatia            1
# GJ Bailey           1
# GD McGrath          1
# MJ McClenaghan      1
# EJG Morgan          1
# A Chandila          1
# Name: win_by_runs, Length: 135, dtype: int64

# %% [markdown]
# <a id=section415></a>

# %% [markdown]
# ### 4.15 Which player received the maximum number of Player of Match award while chasing the target?

# %%
MOM_wickets=ipl[ipl['win_by_wickets']>2].groupby(['player_of_match'])['win_by_wickets'].count().sort_values(ascending = False)
MOM_wickets
# Out:
# player_of_match
# YK Pathan            11
# G Gambhir            10
# RG Sharma             9
# CH Gayle              9
# JH Kallis             8
# DR Smith              8
# DA Warner             7
# MS Dhoni              7
# V Sehwag              7
# V Kohli               7
# AB de Villiers        7
# SR Watson             7
# AM Rahane             7
# UT Yadav              6
# AC Gilchrist          5
# SK Raina              5
# SP Narine             5
# AT Rayudu             4
# SE Marsh              4
# RA Jadeja             4
# RV Uthappa            4
# BJ Hodge              4
# A Mishra              4
# A Nehra               4
# AJ Finch              4
# AD Russell            4
# MEK Hussey            4
# NM Coulter-Nile       3
# CA Lynn               3
# KP Pietersen          3
#                      ..
# P Parameswaran        1
# P Kumar               1
# MA Starc              1
# KK Cooper             1
# KV Sharma             1
# Kuldeep Yadav         1
# L Balaji              1
# L Ngidi               1
# LMP Simmons           1
# LR Shukla             1
# M Kartik              1
# M Ntini               1
# M Ur Rahman           1
# Yuvraj Singh          1
# MA Agarwal            1
# MD Mishra             1
# Mustafizur Rahman     1
# MF Maharoof           1
# MG Johnson            1
# MJ Lumb               1
# MJ McClenaghan        1
# MK Tiwary             1
# MM Sharma             1
# MP Stoinis            1
# MR Marsh              1
# MS Bisla              1
# Mandeep Singh         1
# Mohammed Shami        1
# Mohammed Siraj        1
# A Kumble              1
# Name: win_by_wickets, Length: 164, dtype: int64

# %% [markdown]
# <a id=section416></a>

# %% [markdown]
# ### 4.16 Player of the Match - Match wise result

# %%
MOM_details=pd.concat([MOM_runs, MOM_wickets], axis=1)
MOM_details
# Out:
# C:\Users\pankajp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                    win_by_runs  win_by_wickets
# A Chandila                 1.0             NaN
# A Kumble                   2.0             1.0
# A Mishra                   6.0             4.0
# A Nehra                    1.0             4.0
# A Singh                    NaN             1.0
# A Symonds                  3.0             NaN
# A Zampa                    1.0             NaN
# AA Jhunjhunwala            1.0             NaN
# AB Dinda                   2.0             NaN
# AB de Villiers            11.0             7.0
# AC Gilchrist               2.0             5.0
# AC Voges                   1.0             NaN
# AD Mascarenhas             NaN             1.0
# AD Mathews                 1.0             NaN
# AD Russell                 2.0             4.0
# AJ Finch                   1.0             4.0
# AJ Tye                     NaN             2.0
# AM Rahane                  5.0             7.0
# AP Tare                    1.0             NaN
# AR Patel                   2.0             2.0
# AS Rajpoot                 2.0             NaN
# AS Yadav                   NaN             1.0
# AT Rayudu                  5.0             4.0
# Azhar Mahmood              1.0             1.0
# B Kumar                    3.0             2.0
# B Lee                      NaN             2.0
# B Stanlake                 NaN             1.0
# BA Bhatt                   1.0             NaN
# BA Stokes                  2.0             1.0
# BB McCullum                3.0             2.0
# ...                        ...             ...
# SM Pollock                 1.0             1.0
# SP Goswami                 NaN             1.0
# SP Narine                  3.0             5.0
# SPD Smith                  2.0             2.0
# SR Tendulkar               5.0             3.0
# SR Watson                  5.0             7.0
# SS Iyer                    2.0             NaN
# ST Jayasuriya              NaN             2.0
# SV Samson                  4.0             1.0
# SW Billings                NaN             1.0
# Sandeep Sharma             3.0             2.0
# Shakib Al Hasan            1.0             1.0
# Shoaib Akhtar              1.0             NaN
# Sohail Tanvir              NaN             2.0
# TA Boult                   1.0             NaN
# TG Southee                 1.0             NaN
# TL Suman                   NaN             1.0
# TM Dilshan                 NaN             1.0
# UT Yadav                   2.0             6.0
# Umar Gul                   NaN             1.0
# V Kohli                    3.0             7.0
# V Sehwag                   3.0             7.0
# VR Aaron                   NaN             1.0
# WP Saha                    2.0             1.0
# WPUJC Vaas                 1.0             NaN
# Washington Sundar          1.0             NaN
# YK Pathan                  4.0            11.0
# YS Chahal                  NaN             1.0
# Yuvraj Singh               3.0             1.0
# Z Khan                     NaN             1.0
#
# [211 rows x 2 columns]

# %%
print(MOM_details.dtypes)
# Out:
# win_by_runs       float64
# win_by_wickets    float64
# dtype: object

# %%
MOM_details['win_by_runs'] = MOM_details['win_by_runs'].fillna(0.0).astype(int) 
MOM_details
# Out:
#                    win_by_runs  win_by_wickets
# A Chandila                   1             NaN
# A Kumble                     2             1.0
# A Mishra                     6             4.0
# A Nehra                      1             4.0
# A Singh                      0             1.0
# A Symonds                    3             NaN
# A Zampa                      1             NaN
# AA Jhunjhunwala              1             NaN
# AB Dinda                     2             NaN
# AB de Villiers              11             7.0
# AC Gilchrist                 2             5.0
# AC Voges                     1             NaN
# AD Mascarenhas               0             1.0
# AD Mathews                   1             NaN
# AD Russell                   2             4.0
# AJ Finch                     1             4.0
# AJ Tye                       0             2.0
# AM Rahane                    5             7.0
# AP Tare                      1             NaN
# AR Patel                     2             2.0
# AS Rajpoot                   2             NaN
# AS Yadav                     0             1.0
# AT Rayudu                    5             4.0
# Azhar Mahmood                1             1.0
# B Kumar                      3             2.0
# B Lee                        0             2.0
# B Stanlake                   0             1.0
# BA Bhatt                     1             NaN
# BA Stokes                    2             1.0
# BB McCullum                  3             2.0
# ...                        ...             ...
# SM Pollock                   1             1.0
# SP Goswami                   0             1.0
# SP Narine                    3             5.0
# SPD Smith                    2             2.0
# SR Tendulkar                 5             3.0
# SR Watson                    5             7.0
# SS Iyer                      2             NaN
# ST Jayasuriya                0             2.0
# SV Samson                    4             1.0
# SW Billings                  0             1.0
# Sandeep Sharma               3             2.0
# Shakib Al Hasan              1             1.0
# Shoaib Akhtar                1             NaN
# Sohail Tanvir                0             2.0
# TA Boult                     1             NaN
# TG Southee                   1             NaN
# TL Suman                     0             1.0
# TM Dilshan                   0             1.0
# UT Yadav                     2             6.0
# Umar Gul                     0             1.0
# V Kohli                      3             7.0
# V Sehwag                     3             7.0
# VR Aaron                     0             1.0
# WP Saha                      2             1.0
# WPUJC Vaas                   1             NaN
# Washington Sundar            1             NaN
# YK Pathan                    4            11.0
# YS Chahal                    0             1.0
# Yuvraj Singh                 3             1.0
# Z Khan                       0             1.0
#
# [211 rows x 2 columns]

# %%
pd.set_option('display.max_rows',1000)
MOM_details['win_by_wickets'] = MOM_details['win_by_wickets'].fillna(0.0).astype(int)
print(MOM_details)
# Out:
#                    win_by_runs  win_by_wickets
# A Chandila                   1               0
# A Kumble                     2               1
# A Mishra                     6               4
# A Nehra                      1               4
# A Singh                      0               1
# A Symonds                    3               0
# A Zampa                      1               0
# AA Jhunjhunwala              1               0
# AB Dinda                     2               0
# AB de Villiers              11               7
# AC Gilchrist                 2               5
# AC Voges                     1               0
# AD Mascarenhas               0               1
# AD Mathews                   1               0
# AD Russell                   2               4
# AJ Finch                     1               4
# AJ Tye                       0               2
# AM Rahane                    5               7
# AP Tare                      1               0
# AR Patel                     2               2
# AS Rajpoot                   2               0
# AS Yadav                     0               1
# AT Rayudu                    5               4
# Azhar Mahmood                1               1
# B Kumar                      3               2
# B Lee                        0               2
# B Stanlake                   0               1
# BA Bhatt                     1               0
# BA Stokes                    2               1
# BB McCullum                  3               2
# BCJ Cutting                  1               0
# BJ Hodge                     2               4
# BW Hilfenhaus                0               2
# CA Lynn                      0               3
# CH Gayle                    10               9
# CH Morris                    0               1
# CJ Anderson                  1               2
# CL White                     1               0
# CR Brathwaite                1               0
# CRD Fernando                 0               1
# DA Miller                    1               2
# DA Warner                    8               7
# DE Bollinger                 1               1
# DJ Bravo                     1               0
# DJ Hooda                     0               1
# DJ Hussey                    0               2
# DJG Sammy                    0               1
# DL Vettori                   0               1
# DP Nannes                    0               1
# DPMD Jayawardene             2               3
# DR Smith                     2               8
# DW Steyn                     2               3
# EJG Morgan                   1               0
# F du Plessis                 0               2
# G Gambhir                    3              10
# GC Smith                     2               0
# GD McGrath                   1               0
# GH Vihari                    0               1
# GJ Bailey                    1               0
# GJ Maxwell                   2               3
# HH Gibbs                     0               1
# HH Pandya                    2               1
# HM Amla                      1               1
# HV Patel                     2               0
# Harbhajan Singh              3               3
# Harmeet Singh                1               1
# I Sharma                     1               1
# IK Pathan                    1               1
# Iqbal Abdulla                1               1
# Ishan Kishan                 1               0
# J Archer                     0               1
# J Botha                      0               1
# JA Morkel                    2               0
# JC Buttler                   1               3
# JD Ryder                     0               1
# JD Unadkat                   2               2
# JDP Oram                     0               1
# JEC Franklin                 0               1
# JH Kallis                    2               8
# JJ Bumrah                    1               1
# JJ Roy                       0               1
# JP Duminy                    3               1
# JP Faulkner                  1               3
# KA Pollard                   7               2
# KC Sangakkara                4               1
# KD Karthik                   2               2
# KH Pandya                    1               1
# KK Cooper                    0               1
# KK Nair                      1               2
# KL Rahul                     0               2
# KM Jadhav                    2               0
# KMDN Kulasekara              1               0
# KP Pietersen                 0               3
# KS Williamson                3               0
# KV Sharma                    0               1
# Kuldeep Yadav                0               1
# L Balaji                     2               1
# L Ngidi                      0               1
# LH Ferguson                  1               0
# LJ Wright                    1               0
# LMP Simmons                  2               1
# LR Shukla                    0               1
# LRPL Taylor                  0               2
# M Kartik                     0               1
# M Morkel                     0               2
# M Muralitharan               2               0
# M Ntini                      1               1
# M Ur Rahman                  0               1
# M Vijay                      4               2
# M Vohra                      0               3
# MA Agarwal                   0               1
# MA Starc                     0               1
# MC Henriques                 2               0
# MD Mishra                    0               1
# MEK Hussey                   8               4
# MF Maharoof                  0               1
# MG Johnson                   1               1
# MJ Lumb                      0               1
# MJ McClenaghan               1               1
# MK Pandey                    2               2
# MK Tiwary                    2               1
# ML Hayden                    2               2
# MM Patel                     0               2
# MM Sharma                    1               1
# MN Samuels                   1               0
# MP Stoinis                   1               1
# MR Marsh                     0               1
# MS Bisla                     0               1
# MS Dhoni                     7               7
# MS Gony                      1               0
# MV Boucher                   0               2
# Mandeep Singh                2               1
# Mohammed Shami               0               1
# Mohammed Siraj               0               1
# Mustafizur Rahman            0               1
# N Rana                       1               3
# NM Coulter-Nile              1               3
# NV Ojha                      1               0
# P Kumar                      1               1
# P Negi                       0               2
# P Parameswaran               0               1
# PA Patel                     2               2
# PC Valthaty                  0               2
# PD Collingwood               1               0
# PP Chawla                    2               1
# PP Ojha                      1               0
# PV Tambe                     1               1
# Q de Kock                    0               1
# R Ashwin                     0               1
# R Bhatia                     1               0
# R Dravid                     2               0
# R McLaren                    1               0
# R Sharma                     1               1
# R Vinay Kumar                0               3
# RA Jadeja                    4               4
# RA Tripathi                  0               1
# RE Levi                      0               1
# RG Sharma                    7               9
# RJ Harris                    0               1
# RP Singh                     0               1
# RR Pant                      1               2
# RS Bopara                    0               1
# RV Uthappa                   3               4
# Rashid Khan                  3               2
# S Aravind                    0               1
# S Badrinath                  0               1
# S Dhawan                     1               3
# S Gopal                      1               0
# S Nadeem                     0               1
# S Sohal                      1               0
# S Sreesanth                  0               1
# SA Asnodkar                  1               0
# SB Jakati                    1               0
# SB Wagh                      0               1
# SC Ganguly                   5               0
# SE Marsh                     3               4
# SK Raina                     9               5
# SK Trivedi                   1               1
# SK Warne                     0               2
# SL Malinga                   2               2
# SM Katich                    0               1
# SM Pollock                   1               1
# SP Goswami                   0               1
# SP Narine                    3               5
# SPD Smith                    2               2
# SR Tendulkar                 5               3
# SR Watson                    5               7
# SS Iyer                      2               0
# ST Jayasuriya                0               2
# SV Samson                    4               1
# SW Billings                  0               1
# Sandeep Sharma               3               2
# Shakib Al Hasan              1               1
# Shoaib Akhtar                1               0
# Sohail Tanvir                0               2
# TA Boult                     1               0
# TG Southee                   1               0
# TL Suman                     0               1
# TM Dilshan                   0               1
# UT Yadav                     2               6
# Umar Gul                     0               1
# V Kohli                      3               7
# V Sehwag                     3               7
# VR Aaron                     0               1
# WP Saha                      2               1
# WPUJC Vaas                   1               0
# Washington Sundar            1               0
# YK Pathan                    4              11
# YS Chahal                    0               1
# Yuvraj Singh                 3               1
# Z Khan                       0               1

# %% [markdown]
# <a id=section417></a>

# %% [markdown]
# ### Venue & Player of The Match wise results!

# %%
MOM_Venue=ipl.loc[ : , 'player_of_match':'venue']
byVenue = MOM_Venue.groupby('venue')
byVenue.describe()
# Out:
#                                                    player_of_match         \
#                                                              count unique
# venue
# Barabati Stadium                                                 7      6
# Brabourne Stadium                                               11     10
# Buffalo Park                                                     3      3
# De Beers Diamond Oval                                            3      3
# Dr DY Patil Sports Academy                                      17     15
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...              11     11
# Dubai International Cricket Stadium                              7      7
# Eden Gardens                                                    70     44
# Feroz Shah Kotla                                                66     51
# Green Park                                                       4      4
# Himachal Pradesh Cricket Association Stadium                     9      8
# Holkar Cricket Stadium                                           9      9
# JSCA International Stadium Complex                               7      6
# Kingsmead                                                       15     15
# M Chinnaswamy Stadium                                           71     44
# MA Chidambaram Stadium, Chepauk                                 49     32
# Maharashtra Cricket Association Stadium                         21     18
# Nehru Stadium                                                    5      5
# New Wanderers Stadium                                            8      7
# Newlands                                                         7      7
# OUTsurance Oval                                                  2      2
# Punjab Cricket Association IS Bindra Stadium, M...              14     13
# Punjab Cricket Association Stadium, Mohali                      35     26
# Rajiv Gandhi International Stadium, Uppal                       56     37
# Sardar Patel Stadium, Motera                                    12     11
# Saurashtra Cricket Association Stadium                          10     10
# Sawai Mansingh Stadium                                          40     29
# Shaheed Veer Narayan Singh International Stadium                 6      5
# Sharjah Cricket Stadium                                          6      5
# Sheikh Zayed Stadium                                             7      7
# St George's Park                                                 7      7
# Subrata Roy Sahara Stadium                                      17     17
# SuperSport Park                                                 12     12
# Vidarbha Cricket Association Stadium, Jamtha                     3      3
# Wankhede Stadium                                                66     45
#
#
#                                                                  top freq
# venue
# Barabati Stadium                                           A Symonds    2
# Brabourne Stadium                                       SR Tendulkar    2
# Buffalo Park                                                MS Dhoni    1
# De Beers Diamond Oval                                       DR Smith    1
# Dr DY Patil Sports Academy                              DE Bollinger    2
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...         KH Pandya    1
# Dubai International Cricket Stadium                          B Kumar    1
# Eden Gardens                                               SP Narine    6
# Feroz Shah Kotla                                            A Mishra    4
# Green Park                                                  DR Smith    1
# Himachal Pradesh Cricket Association Stadium            AC Gilchrist    2
# Holkar Cricket Stadium                                   M Ur Rahman    1
# JSCA International Stadium Complex                         RA Jadeja    2
# Kingsmead                                             AB de Villiers    1
# M Chinnaswamy Stadium                                       CH Gayle    9
# MA Chidambaram Stadium, Chepauk                           MEK Hussey    5
# Maharashtra Cricket Association Stadium               AB de Villiers    2
# Nehru Stadium                                         AB de Villiers    1
# New Wanderers Stadium                                      JH Kallis    2
# Newlands                                                  DL Vettori    1
# OUTsurance Oval                                                B Lee    1
# Punjab Cricket Association IS Bindra Stadium, M...          CH Gayle    2
# Punjab Cricket Association Stadium, Mohali                  SE Marsh    5
# Rajiv Gandhi International Stadium, Uppal                  DA Warner    7
# Sardar Patel Stadium, Motera                               AM Rahane    2
# Saurashtra Cricket Association Stadium                      AJ Finch    1
# Sawai Mansingh Stadium                                     AM Rahane    4
# Shaheed Veer Narayan Singh International Stadium           DA Warner    2
# Sharjah Cricket Stadium                                   GJ Maxwell    2
# Sheikh Zayed Stadium                                        PV Tambe    1
# St George's Park                                    DPMD Jayawardene    1
# Subrata Roy Sahara Stadium                            AB de Villiers    1
# SuperSport Park                                             V Sehwag    1
# Vidarbha Cricket Association Stadium, Jamtha                SK Warne    1
# Wankhede Stadium                                           RG Sharma    7

# %% [markdown]
# <a id=section7></a>

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ## Cricket one of the most loved and favourite sports entertainment specially in India. Here I present data analysis for IPL (Indian Premier League) matches from the beginning till year 2018. This can be useful for all the cricket lovers to analyse and made quick decisions based out from this. Few of which can be like; Which cricketer has scored the most for a particular season? or Which factors affect winning rate ? few of which can be toss decision and venue of the match played ! Various visual along with custom one have been used with filters and drill down capability.
# ## Also it will addresses the player profiling system which can be a great help for the team leaders on the auction day. The statistics of 644 matches have been used in the experiments.
